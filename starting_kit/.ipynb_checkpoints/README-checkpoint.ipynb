# %% [markdown]
# <div style="background:#FFFFFF">
# <img src="logo.jpg" width=150 ALIGN="left" style='margin-right:10px; border-style: solid; border-width: 2px;' alt='logo'>
# <h1>Starting Kit - Insects Classification </h1>
# <p>
# This starting kit will guide you step by step and will walk you through the data statistics and<br>
# examples. This will give you a clear idea of what this challenge is about and how you can<br>
# proceed further to solve the challenge.
# </p>
#
# <br><br>
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
# <p>
# This code was tested with Python 3.8.5 |Anaconda custom (64-bit)| (default, Dec 23 2020, 21:19:02) (https://anaconda.org/)<br>
# </p>
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
#
# <p>
# ALL INFORMATION, SOFTWARE, DOCUMENTATION, AND DATA ARE PROVIDED "AS-IS". The CHALEARN, AND/OR OTHER ORGANIZERS OR CODE AUTHORS DISCLAIM ANY EXPRESSED OR IMPLIED WARRANTIES, INCLUDING, BUT NOT LIMITED TO, THE IMPLIED WARRANTIES OF MERCHANTABILITY AND FITNESS FOR ANY PARTICULAR PURPOSE, AND THE WARRANTY OF NON-INFRIGEMENT OF ANY THIRD PARTY'S INTELLECTUAL PROPERTY RIGHTS. IN NO EVENT SHALL AUTHORS AND ORGANIZERS BE LIABLE FOR ANY SPECIAL,
# INDIRECT OR CONSEQUENTIAL DAMAGES OR ANY DAMAGES WHATSOEVER ARISING OUT OF OR IN CONNECTION WITH THE USE OR PERFORMANCE OF SOFTWARE, DOCUMENTS, MATERIALS, PUBLICATIONS, OR INFORMATION MADE AVAILABLE FOR THE CHALLENGE.
# </p>
#
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>
#     <p>
# This challenge was organized by <b>Team Ecologists</b> of <b><a style='color:#4D6605;' href='http://www.chalearn.org/'>ChaLearn</a></b>  at <b><a style='color: #62023C;' href='https://www.universite-paris-saclay.fr/'>Université Paris Saclay</a></b>
# </p>
# </div>
#
# <hr style='background-color: #D3D3D3; height: 1px; border: 0;'>

# %% [markdown]
# ***
# # Introduction
#
# This challenge uses a Dataset from ***MUSÉUM NATIONAL D’HISTOIRE NATURELLE***
#
#
# The sample dataset coniststs of total **12** images and each image belongs to one of the following classes
#
#     - Bee
#     - Wasp
#     - Butterfly insect
#     - Insect
#
#
# This challenge is about creating a Machine Learning model and train it with the data provided to classify the images into the mentioned 5 categories.
#
#
# **References and credits:**
#  - MUSÉUM NATIONAL D’HISTOIRE NATURELLE (https://www.mnhn.fr/)
#  - SPIPOLL (https://www.spipoll.org/)
#  - Université Paris Saclay (https://www.universite-paris-saclay.fr/)
#  - ChaLearn (http://www.chalearn.org/)
# ***

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
model_dir = 'sample_code_submission/' # Change the model to a better one once you have one!
result_dir = 'sample_result_submission/' 
problem_dir = 'ingestion_program/'  
score_dir = 'scoring_program/'
from sys import path; path.append(model_dir); path.append(problem_dir); path.append(score_dir); 
# %matplotlib inline
# Uncomment the next lines to auto-reload libraries (this causes some problem with pickles in Python 3)
# %load_ext autoreload
# %autoreload 2
import seaborn as sns; sns.set()
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# %reload_ext autoreload

# %% [markdown]
# ***
# # Step 1: Exploratory data analysis
# We provide `sample_data` with the starting kit, but to prepare your submission, you must fetch the `public_data` from the challenge website and point to it.
#
# The data used for this challenge has images resized into 128x128 pixels.

# %%
data_name = 'insect_challenge' # DO NOT CHANGE
data_dir = 'sample_data' # Change it to point to the directory with public_data
# !ls $data_dir*

# %% [markdown]
# ### Load Data

# %%
from data_io import read_data
data, meta_data = read_data(data_dir)
# Out:
# ###-------------------------------------###
# ### Checking Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Your dataset is in perfect format
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Data
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Data loaded successfully
# -------------------------------------
#
#
# ###-------------------------------------###
# ### Loading Images
# ###-------------------------------------###
#
#
# -------------------------------------
# [+] Images loaded successfully
# -------------------------------------

# %% [markdown]
# ### Data Statistics

# %%
print("Categories/Classes : ", data['categories'])
print("Number of images : ", data['images'].sum())
print("Train Images:", len(data['train_images']))
print("Test Images:", len(data['train_images']))
# Out:
# Categories/Classes :  ['bee' 'butterfly' 'insect' 'wasp']
# Number of images :  12
# Train Images: 6
# Test Images: 6

# %% [markdown]
# ### Meta-Data

# %%
for key, value in meta_data.items():
    print(key, " : ", value)
# Out:
# dataset_name  :  insect_sample_data
# dataset_description  :  insect sample mini dataset
# total_categories  :  4
# total_super_categorie  :  0
# uniform_number_of_images_per_category  :  True
# images_per_category  :  3
# has_super_categories  :  False
# image_column_name  :  FILE_NAME
# category_column_name  :  CATEGORY
# csv_with_tab  :  False

# %% [markdown]
# ### Distribution of Classes/Labels

# %%
plt.figure(figsize=(10, 5))
plt.bar(data['categories'], data['images'])
plt.xlabel("Labels/Classes")
plt.ylabel("Number of images")
plt.title("Distribution of Classes");

# %% [markdown]
# ### Visualization

# %%
data["train_labels"]
# Out:
# array(['insect', 'butterfly', 'wasp', 'bee', 'insect', 'wasp'],
#       dtype=object)

# %%
number_of_images_to_show = 6

images = data["train_images"]
labels = data["train_labels"]
      


fig, _axs = plt.subplots(nrows=2, ncols=3, figsize=(8,5))
fig.subplots_adjust(hspace=0.3)
axs = _axs.flatten()


for i in range(number_of_images_to_show):
    img = images[i]
    label = labels[i]
    axs[i].set_title('Example of {}'.format(label))
    axs[i].imshow(img)
    axs[i].set_axis_off()

plt.show()

# %% [markdown]
# ***
# # Step 2: Building a predictive model

# %% [markdown]
# ## Training a predictive model
# We provide an example of predictive model in the `sample_code_submission/` directory.
# You can change this model and use a better one to get a good score for the challenge

# %% [markdown]
# **Install pre-requisites for using the model from Keras**
#
# Uncomment the next line

# %%
# !pip install --user --upgrade tensorflow
# !pip install keras

# %%
from data_io import write
from model import model

# %% [markdown]
# <div style="background:#FFF">
# an instance of the model (run the constructor) and attempt to reload a previously saved version from `sample_code_submission/`:
# </div>

# %%
myModel = model()
trained_model_name = model_dir + data_name
# Uncomment the next line to re-load an already trained model
#myModel = myModel.load(trained_model_name)
# Out:
# Model: <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f9e46f90d10>

# %% [markdown]
# <div style="background:#FFF">
#     Train the model (unless you reloaded a trained model) and make predictions.
# </div>

# %%
if not(myModel.is_trained):
    myModel.fit(data["X_train"], data["Y_train"])                     

Y_hat_train = myModel.predict(data["X_train"]) # Optional, not really needed to test on taining examples

if data["has_valid"]:
    Y_hat_valid = myModel.predict(data["X_valid"])

if data["has_test"]:
    Y_hat_test = myModel.predict(data["X_test"])
# Out:
# FIT: dim(X)= [10000, 49152]
# FIT: dim(y)= [10000, 1]
# Epoch 1/10
# 80/80 [==============================] - 43s 509ms/step - loss: 1.6616 - accuracy: 0.2727 - val_loss: 1.3273 - val_accuracy: 0.4465
# Epoch 2/10
# 80/80 [==============================] - 41s 513ms/step - loss: 1.2687 - accuracy: 0.4735 - val_loss: 1.1484 - val_accuracy: 0.5315
# Epoch 3/10
# 80/80 [==============================] - 39s 483ms/step - loss: 1.1425 - accuracy: 0.5476 - val_loss: 1.0909 - val_accuracy: 0.5525
# Epoch 4/10
# 80/80 [==============================] - 42s 530ms/step - loss: 1.0197 - accuracy: 0.5961 - val_loss: 1.0564 - val_accuracy: 0.5735
# Epoch 5/10
# 80/80 [==============================] - 42s 528ms/step - loss: 0.9184 - accuracy: 0.6414 - val_loss: 1.0682 - val_accuracy: 0.5590
# Epoch 6/10
# 80/80 [==============================] - 42s 523ms/step - loss: 0.8296 - accuracy: 0.6802 - val_loss: 1.1029 - val_accuracy: 0.5655
# Epoch 7/10
# 80/80 [==============================] - 45s 566ms/step - loss: 0.6926 - accuracy: 0.7335 - val_loss: 1.0997 - val_accuracy: 0.5840
# Epoch 8/10
# 80/80 [==============================] - 45s 561ms/step - loss: 0.6566 - accuracy: 0.7644 - val_loss: 1.1580 - val_accuracy: 0.5745
# Epoch 9/10
# 80/80 [==============================] - 41s 515ms/step - loss: 0.3991 - accuracy: 0.8637 - val_loss: 1.3041 - val_accuracy: 0.5605
# Epoch 10/10
# 80/80 [==============================] - 43s 537ms/step - loss: 0.2349 - accuracy: 0.9303 - val_loss: 1.4042 - val_accuracy: 0.5575
# FIT: Training Successful
# PREDICT: dim(X)= [10000, 49152]
# PREDICT: dim(y)= [10000, 1]
# PREDICT: Prediction done

# %% [markdown]
# **Save the trained model** (will be ready to reload next time around) and save the prediction results. <br>

# %%
myModel.save(trained_model_name)
# Out:
# Model Saved : sample_code_submission/deep_pollination_model.h5

# %% [markdown]
# **IMPORTANT:** if you save the trained model, it will be bundled with your sample code submission. Therefore your model will NOT be retrained on the challenge platform. Remove the pickle from the submission if you want the model to be retrained on the platform.
#
# **REQUIRED:** Trained model is required in the submission to codalab.

# %%
result_name = result_dir + data_name
from data_io import write
write(result_name + '_train.predict', Y_hat_train)

if data["has_valid"]:
    write(result_name + '_valid.predict', Y_hat_valid)

if data["has_test"]:
    write(result_name + '_test.predict', Y_hat_test)

# !ls $result_name*
# Out:
# sample_result_submission/deep_pollination_train.predict

# %% [markdown]
# ## Scoring the results
# ### Load the challenge metric
#
# **The metric chosen for your challenge** is identified in the "metric.txt" file found in the `scoring_program/` directory.
# <br>
# The function "get_metric" searches first for a metric having that name in my_metric.py, then in libscores.py, then in sklearn.metric.

# %%
from libscores import get_metric
metric_name, scoring_function = get_metric()
print('Using scoring metric:', metric_name)
# Uncomment the next line to display the code of the scoring metric
#??scoring_function
# Out:
# Using scoring metric: accuracy

# %% [markdown]
# ## Training performance

# %%
print('Training score for the', metric_name, 'metric = %5.4f' % scoring_function(data["Y_train"], Y_hat_train))
print('Ideal score for the', metric_name, 'metric = %5.4f' % scoring_function(data["Y_train"], data["Y_train"]))

if data["has_valid"]:
    print('Validation score for the', metric_name, 'metric = %5.4f' % scoring_function(data["Y_valid"], Y_hat_valid))
if data["has_test"]:
    print('Test score for the', metric_name, 'metric = %5.4f' % scoring_function(data["Y_test"], Y_hat_test))
# Out:
# Training score for the accuracy metric = 0.8831
# Ideal score for the accuracy metric = 1.0000

# %% [markdown]
# You can add here other scores and result visualization.

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix = confusion_matrix(data["Y_train"], Y_hat_train)

# %%
confusion_matrix
# Out:
# array([[1744,   69,  110,   33,   44],
#        [  51, 1841,   42,   45,   21],
#        [ 202,  105, 1615,   35,   43],
#        [  17,   38,   17, 1925,    3],
#        [ 122,   44,  111,   17, 1706]])

# %%
df_cm = pd.DataFrame(confusion_matrix, range(confusion_matrix.shape[0]), range(confusion_matrix.shape[1]))
sns.heatmap(df_cm, annot=True)
plt.title("Train - Confustion Matrix")
plt.show()

# %% [markdown]
# ## Cross-validation performance
#
# CV scores on sample_data doesn't have enough data, and so isn't meaningful.
# Run it with the full data to see meaningful values.

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
scores = cross_val_score(myModel, data["X_train"], data["Y_train"], cv=3, scoring=make_scorer(scoring_function))
print('\nCV score (95 perc. CI): %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
# Out:
# Model: <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f9c59311c90>
# FIT: dim(X)= [6666, 49152]
# FIT: dim(y)= [6666, 1]
# Epoch 1/10
# 54/54 [==============================] - 29s 520ms/step - loss: 1.5927 - accuracy: 0.2669 - val_loss: 1.4866 - val_accuracy: 0.3148
# Epoch 2/10
# 54/54 [==============================] - 28s 516ms/step - loss: 1.3482 - accuracy: 0.4408 - val_loss: 1.2937 - val_accuracy: 0.4543
# Epoch 3/10
# 54/54 [==============================] - 28s 511ms/step - loss: 1.2108 - accuracy: 0.4982 - val_loss: 1.6271 - val_accuracy: 0.4025
# Epoch 4/10
# 54/54 [==============================] - 29s 539ms/step - loss: 1.1142 - accuracy: 0.5614 - val_loss: 1.5354 - val_accuracy: 0.4280
# Epoch 5/10
# 54/54 [==============================] - 29s 543ms/step - loss: 1.0102 - accuracy: 0.6096 - val_loss: 1.2235 - val_accuracy: 0.5187
# Epoch 6/10
# 54/54 [==============================] - 29s 542ms/step - loss: 0.8405 - accuracy: 0.6729 - val_loss: 1.3316 - val_accuracy: 0.5000
# Epoch 7/10
# 54/54 [==============================] - 28s 526ms/step - loss: 0.6858 - accuracy: 0.7420 - val_loss: 1.3282 - val_accuracy: 0.5330
# Epoch 8/10
# 54/54 [==============================] - 30s 552ms/step - loss: 0.5180 - accuracy: 0.8194 - val_loss: 1.5601 - val_accuracy: 0.5300
# Epoch 9/10
# 54/54 [==============================] - 28s 520ms/step - loss: 0.2906 - accuracy: 0.9048 - val_loss: 1.5140 - val_accuracy: 0.5180
# Epoch 10/10
# 54/54 [==============================] - 29s 528ms/step - loss: 0.1517 - accuracy: 0.9608 - val_loss: 2.3338 - val_accuracy: 0.5030
# FIT: Training Successful
# PREDICT: dim(X)= [3334, 49152]
# PREDICT: dim(y)= [3334, 1]
# PREDICT: Prediction done
# Model: <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f9c5da68750>
# FIT: dim(X)= [6667, 49152]
# FIT: dim(y)= [6667, 1]
# Epoch 1/10
# 54/54 [==============================] - 32s 553ms/step - loss: 1.6513 - accuracy: 0.2769 - val_loss: 1.3503 - val_accuracy: 0.4430
# Epoch 2/10
# 54/54 [==============================] - 26s 487ms/step - loss: 1.3181 - accuracy: 0.4523 - val_loss: 1.4281 - val_accuracy: 0.3868
# Epoch 3/10
# 54/54 [==============================] - 30s 563ms/step - loss: 1.1694 - accuracy: 0.5400 - val_loss: 1.2794 - val_accuracy: 0.4753
# Epoch 4/10
# 54/54 [==============================] - 29s 529ms/step - loss: 1.0931 - accuracy: 0.5647 - val_loss: 1.1641 - val_accuracy: 0.5247
# Epoch 5/10
# 54/54 [==============================] - 28s 522ms/step - loss: 0.9694 - accuracy: 0.6305 - val_loss: 1.4305 - val_accuracy: 0.4100
# Epoch 6/10
# 54/54 [==============================] - 29s 533ms/step - loss: 0.8989 - accuracy: 0.6479 - val_loss: 1.2020 - val_accuracy: 0.5142
# Epoch 7/10
# 54/54 [==============================] - 29s 543ms/step - loss: 0.7725 - accuracy: 0.7011 - val_loss: 1.2387 - val_accuracy: 0.5472
# Epoch 8/10
# 54/54 [==============================] - 30s 560ms/step - loss: 0.6081 - accuracy: 0.7719 - val_loss: 1.2472 - val_accuracy: 0.5397
# Epoch 9/10
# 54/54 [==============================] - 30s 546ms/step - loss: 0.4309 - accuracy: 0.8488 - val_loss: 1.4821 - val_accuracy: 0.5262
# Epoch 10/10
# 54/54 [==============================] - 28s 522ms/step - loss: 0.2418 - accuracy: 0.9258 - val_loss: 1.6123 - val_accuracy: 0.5067
# FIT: Training Successful
# PREDICT: dim(X)= [3333, 49152]
# PREDICT: dim(y)= [3333, 1]
# PREDICT: Prediction done
# Model: <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f9c5da5fa90>
# FIT: dim(X)= [6667, 49152]
# FIT: dim(y)= [6667, 1]
# Epoch 1/10
# 54/54 [==============================] - 27s 465ms/step - loss: 1.6572 - accuracy: 0.2719 - val_loss: 1.4621 - val_accuracy: 0.3643
# Epoch 2/10
# 54/54 [==============================] - 24s 451ms/step - loss: 1.3460 - accuracy: 0.4333 - val_loss: 1.2559 - val_accuracy: 0.5007
# Epoch 3/10
# 54/54 [==============================] - 24s 446ms/step - loss: 1.1514 - accuracy: 0.5288 - val_loss: 1.1650 - val_accuracy: 0.5367
# Epoch 4/10
# 54/54 [==============================] - 25s 468ms/step - loss: 1.0360 - accuracy: 0.5868 - val_loss: 1.2170 - val_accuracy: 0.5075
# Epoch 5/10
# 54/54 [==============================] - 27s 495ms/step - loss: 0.9114 - accuracy: 0.6370 - val_loss: 1.1424 - val_accuracy: 0.5637
# Epoch 6/10
# 54/54 [==============================] - 28s 520ms/step - loss: 0.8275 - accuracy: 0.6868 - val_loss: 1.1844 - val_accuracy: 0.5720
# Epoch 7/10
# 54/54 [==============================] - 29s 529ms/step - loss: 0.6253 - accuracy: 0.7687 - val_loss: 1.4220 - val_accuracy: 0.4963
# Epoch 8/10
# 54/54 [==============================] - 27s 502ms/step - loss: 0.4585 - accuracy: 0.8403 - val_loss: 1.4121 - val_accuracy: 0.5682
# Epoch 9/10
# 54/54 [==============================] - 26s 479ms/step - loss: 0.2577 - accuracy: 0.9223 - val_loss: 1.6020 - val_accuracy: 0.5262
# Epoch 10/10
# 54/54 [==============================] - 27s 494ms/step - loss: 0.1480 - accuracy: 0.9612 - val_loss: 1.7219 - val_accuracy: 0.5232
# FIT: Training Successful
# PREDICT: dim(X)= [3333, 49152]
# PREDICT: dim(y)= [3333, 1]
# PREDICT: Prediction done
#
# CV score (95 perc. CI): 0.52 (+/- 0.02)

# %% [markdown]
# ***
# # Step 3: Making a submission
#
# ## Unit testing
#
# It is <b><span style="color:red">important that you test your submission files before submitting them</span></b>. All you have to do to make a submission is modify the file <code>model.py</code> in the <code>sample_code_submission/</code> directory, then run this test to make sure everything works fine. This is the actual program that will be run on the server to test your submission.
# <br>
# Keep the sample code simple.<br>
#
# <code>python3</code> is required for this step

# %%
# !source activate python3; python $problem_dir/ingestion.py $data_dir $result_dir $problem_dir $model_dir
# Out:
# Could not find conda environment: python3
# You can list all discoverable environments with `conda info --envs`.
#
# Using input_dir: /Users/ihsan/Desktop/Paris Saclay/Semester 1/T3/Project A/Bees/STARTING_KIT_2/starting_kit/public_data
# Using output_dir: /Users/ihsan/Desktop/Paris Saclay/Semester 1/T3/Project A/Bees/STARTING_KIT_2/starting_kit/sample_result_submission
# Using program_dir: /Users/ihsan/Desktop/Paris Saclay/Semester 1/T3/Project A/Bees/STARTING_KIT_2/starting_kit/ingestion_program
# Using submission_dir: /Users/ihsan/Desktop/Paris Saclay/Semester 1/T3/Project A/Bees/STARTING_KIT_2/starting_kit/sample_code_submission
# Data name: deep_pollination
#
# ========== Ingestion program version 6 ==========
#
# ************************************************
# ******** Processing dataset Deep_pollination ********
# ************************************************
# ========= Reading and converting data ==========
# ------------------------------------
# Reading File Names
# ------------------------------------
#
# Number of images : 10000
#
# Train Images: 10000
#
# Validation Images: 0
#
# Test Images: 0
#
#
# ------------------------------------
# Reading Label Names
# ------------------------------------
#
# Class Names :  ['bee' 'butterfly' 'insect' 'other' 'wasp']
#
# ------------------------------------
# Reading Images
# ------------------------------------
#
#
# Reading Train Images
#
# Train Images Read:  10000
#
#
#
# Data prepration successfully!
# #--WARNING--# Validation Data NOT Found!
# #--WARNING--# Test Data NOT Found!
# [+] Cumulated time budget (all tasks so far)  500.00 sec
# [+] Time budget for this task 500.00 sec
# [+] Remaining time after reading data 482.76 sec
# ======== Creating model ==========
# 2021-03-02 19:46:12.521120: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-02 19:46:12.521387: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: <tensorflow.python.keras.engine.sequential.Sequential object at 0x7fbf8cdf1710>
# **********************************************************
# ****** Attempting to reload model to avoid training ******
# **********************************************************
# Model reloaded from: /Users/ihsan/Desktop/Paris Saclay/Semester 1/T3/Project A/Bees/STARTING_KIT_2/starting_kit/sample_code_submission/deep_pollination_model.h5
# [+] Model reloaded!
# PREDICT: dim(X)= [10000, 49152]
# ARRGH: number of features in X does not match training data!
# PREDICT: dim(y)= [10000, 1]
# 2021-03-02 19:46:18.348562: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# PREDICT: Prediction done
# [+] Prediction success, time spent so far 37.51 sec
# ======== Saving results to: /Users/ihsan/Desktop/Paris Saclay/Semester 1/T3/Project A/Bees/STARTING_KIT_2/starting_kit/sample_result_submission
# [+] Results saved, time spent so far 37.52 sec
# [+] End cycle, time left 462.48 sec
# [+] Done
# [+] Overall time spent 42.75 sec ::  Overall time budget 500.00 sec

# %% [markdown]
# ### Test scoring program

# %%
scoring_output_dir = 'scoring_output'
# !source activate python3; python $score_dir/score.py $data_dir $result_dir $scoring_output_dir
# Out:
# Could not find conda environment: python3
# You can list all discoverable environments with `conda info --envs`.
#
# ------------------------------------
# Reading Solutions
# ------------------------------------
#
# Number of solutions : 10000
#
# Train solutions: 10000
#
# Validation solutions: 0
#
# Test solutions: 0
#
#
# Solutions files are ready!
# ======= Set 1 (Deep_pollination_train): accuracy(set1_score)=0.883100000000 =======
# #--ERROR--# Valid predict file NOT Found!
# ======= Set 2 (Deep_pollination_valid): accuracy(set2_score)=ERROR =======
# #--ERROR--# Test predict file NOT Found!
# ======= Set 3 (Deep_pollination_test): accuracy(set3_score)=ERROR =======

# %% [markdown]
# # Prepare the submission

# %%
import datetime 
from data_io import zipdir
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
sample_code_submission = '../sample_code_submission_' + the_date + '.zip'
sample_result_submission = '../sample_result_submission_' + the_date + '.zip'
zipdir(sample_code_submission, model_dir)
zipdir(sample_result_submission, result_dir)
print("Submit one of these files:\n" + sample_code_submission + "\n" + sample_result_submission)
# Out:
# Submit one of these files:
# ../sample_code_submission_21-03-02-19-48.zip
# ../sample_result_submission_21-03-02-19-48.zip
